# %%
import calour as ca
import calour_utils as cu
# Out:
# failed to load logging config file

# %%
ca.set_log_level('INFO')

# %%
# %matplotlib notebook

# %%
tt=ca.read_amplicon('/Users/amnon/Projects/sheba/lung-cancer/feature-table.biom',
                    '/Users/amnon/Projects/sheba/lung-cancer/DB_2_3_5_7_10_11_lungs_ctrl_map_v3.txt',
                    normalize=10000, min_reads=1000)
# Out:
# 2020-07-06 13:25:04 INFO loaded 82 samples, 2064 features
# 2020-07-06 13:25:04 INFO After filtering, 82 remaining

# %%
tt=tt.cluster_features(10)
# Out:
# 2020-07-06 13:25:04 INFO After filtering, 1173 remaining

# %%
dd=tt.diff_abundance('Dx','healthy',alpha=0.25)
# Out:
# 2020-07-06 13:25:04 INFO After filtering, 1173 remaining
# 2020-07-06 13:25:04 INFO 28 samples with value 1 (['healthy'])
# 2020-07-06 13:25:05 INFO number of higher in healthy: 101. number of higher in NOT healthy : 69. total 170

# %%
cu.splot(dd,'Dx')
# Out:
# 2020-07-06 13:25:12 INFO Getting dbBact annotations for 170 sequences, please wait...
# 2020-07-06 13:25:17 INFO got 1957 annotations
# 2020-07-06 13:25:17 INFO Got 12502 annotation-sequence pairs
# 2020-07-06 13:25:17 INFO Added annotation data to experiment. Total 1957 annotations, 170 terms
# 2020-07-06 13:25:18 WARNING No experiment found matching the details [['DataMD5', '4dd402e9084209fd7f52640c24b1cdec'], ['MapMD5', '7346c28b20a4fb0d6b91e1911f4eec8e']]
# 2020-07-06 13:25:18 WARNING No matching experiment found in dbBact. Not ignoring any experiments

# %%
dd.plot_diff_abundance_enrichment()
# Out:
# 2020-07-06 13:26:49 INFO Getting dbBact annotations for 170 sequences, please wait...
# 2020-07-06 13:26:54 INFO got 1957 annotations
# 2020-07-06 13:26:54 INFO Got 12502 annotation-sequence pairs
# 2020-07-06 13:26:54 INFO Added annotation data to experiment. Total 1957 annotations, 170 terms
# <img src="data:image/png;base64,..." width="640">
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fd19f190890>,
#  Experiment with 170 samples, 432 features)

# %%
db=ca.database._get_database_class('dbbact')

# %%
import dbbact_calour as dbc

# %%
import dbbact_calour.enrichment_gui as eg

# %%
g1=dd.feature_metadata[dd.feature_metadata._calour_direction=='healthy'].index.values

# %%
len(g1)

# %%
res=eg.show_enriched_terms_qt5(db,g1,None,exp=dd)

# %% [raw]
# res

# %%
tt.cluster_data()
